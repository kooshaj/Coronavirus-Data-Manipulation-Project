# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plots
import math
import ipywidgets as widgets
from IPython.display import display
from datetime import datetime

# %%
covid1 = pd.read_csv("covid_data_1.csv")
covid1
# Out:
#       iso_code      continent       location        date  total_cases  \
# 0          ABW  North America          Aruba  2020-03-13          2.0
# 1          ABW  North America          Aruba  2020-03-19          NaN
# 2          ABW  North America          Aruba  2020-03-20          4.0
# 3          ABW  North America          Aruba  2020-03-21          NaN
# 4          ABW  North America          Aruba  2020-03-22          NaN
# ...        ...            ...            ...         ...          ...
# 44147      NaN            NaN  International  2020-09-12        696.0
# 44148      NaN            NaN  International  2020-09-13        696.0
# 44149      NaN            NaN  International  2020-09-14        696.0
# 44150      NaN            NaN  International  2020-09-15        696.0
# 44151      NaN            NaN  International  2020-09-16        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            2.0                 NaN           0.0         0.0
# 1            NaN               0.286           NaN         NaN
# 2            2.0               0.286           0.0         0.0
# 3            NaN               0.286           NaN         NaN
# 4            NaN               0.286           NaN         NaN
# ...          ...                 ...           ...         ...
# 44147        NaN                 NaN           7.0         NaN
# 44148        NaN                 NaN           7.0         NaN
# 44149        NaN                 NaN           7.0         NaN
# 44150        NaN                 NaN           7.0         NaN
# 44151        NaN                 NaN           7.0         NaN
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 0                      NaN  ...       35973.781              NaN
# 1                      0.0  ...       35973.781              NaN
# 2                      0.0  ...       35973.781              NaN
# 3                      0.0  ...       35973.781              NaN
# 4                      0.0  ...       35973.781              NaN
# ...                    ...  ...             ...              ...
# 44147                  NaN  ...             NaN              NaN
# 44148                  NaN  ...             NaN              NaN
# 44149                  NaN  ...             NaN              NaN
# 44150                  NaN  ...             NaN              NaN
# 44151                  NaN  ...             NaN              NaN
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 0                        NaN                11.62             NaN
# 1                        NaN                11.62             NaN
# 2                        NaN                11.62             NaN
# 3                        NaN                11.62             NaN
# 4                        NaN                11.62             NaN
# ...                      ...                  ...             ...
# 44147                    NaN                  NaN             NaN
# 44148                    NaN                  NaN             NaN
# 44149                    NaN                  NaN             NaN
# 44150                    NaN                  NaN             NaN
# 44151                    NaN                  NaN             NaN
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0               NaN                     NaN                         NaN
# 1               NaN                     NaN                         NaN
# 2               NaN                     NaN                         NaN
# 3               NaN                     NaN                         NaN
# 4               NaN                     NaN                         NaN
# ...             ...                     ...                         ...
# 44147           NaN                     NaN                         NaN
# 44148           NaN                     NaN                         NaN
# 44149           NaN                     NaN                         NaN
# 44150           NaN                     NaN                         NaN
# 44151           NaN                     NaN                         NaN
#
#        life_expectancy  human_development_index
# 0                76.29                      NaN
# 1                76.29                      NaN
# 2                76.29                      NaN
# 3                76.29                      NaN
# 4                76.29                      NaN
# ...                ...                      ...
# 44147              NaN                      NaN
# 44148              NaN                      NaN
# 44149              NaN                      NaN
# 44150              NaN                      NaN
# 44151              NaN                      NaN
#
# [44152 rows x 41 columns]

# %%
def death_rate_calculator(row):
    total_deaths = row["total_deaths"]
    pos_cases = row["total_cases"]
    if (np.isnan(pos_cases) or (np.isnan(total_deaths))):
        return None
    if ((np.isnan(pos_cases) == 0 )or (np.isnan(total_deaths)) == 0):
        return 0
    else:
        return total_deaths / pos_cases
def pos_rate_calculator(row):
    pos_cases = row["total_cases"]
    total_tests = row["total_tests"]
    if (np.isnan(pos_cases) or (np.isnan(total_tests))):
        return None
    if ((np.isnan(pos_cases) == 0 )or (np.isnan(total_tests)) == 0):
        return 0
    else:
        return pos_cases / total_tests
covid1["death_rate"] = covid1.apply(death_rate_calculator, axis = 1)
covid1["positive_rate"] = covid1.apply(pos_rate_calculator, axis = 1)
covid1
# Out:
#       iso_code      continent       location        date  total_cases  \
# 0          ABW  North America          Aruba  2020-03-13          2.0
# 1          ABW  North America          Aruba  2020-03-19          NaN
# 2          ABW  North America          Aruba  2020-03-20          4.0
# 3          ABW  North America          Aruba  2020-03-21          NaN
# 4          ABW  North America          Aruba  2020-03-22          NaN
# ...        ...            ...            ...         ...          ...
# 44147      NaN            NaN  International  2020-09-12        696.0
# 44148      NaN            NaN  International  2020-09-13        696.0
# 44149      NaN            NaN  International  2020-09-14        696.0
# 44150      NaN            NaN  International  2020-09-15        696.0
# 44151      NaN            NaN  International  2020-09-16        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            2.0                 NaN           0.0         0.0
# 1            NaN               0.286           NaN         NaN
# 2            2.0               0.286           0.0         0.0
# 3            NaN               0.286           NaN         NaN
# 4            NaN               0.286           NaN         NaN
# ...          ...                 ...           ...         ...
# 44147        NaN                 NaN           7.0         NaN
# 44148        NaN                 NaN           7.0         NaN
# 44149        NaN                 NaN           7.0         NaN
# 44150        NaN                 NaN           7.0         NaN
# 44151        NaN                 NaN           7.0         NaN
#
#        new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# 0                      NaN  ...              NaN                    NaN
# 1                      0.0  ...              NaN                    NaN
# 2                      0.0  ...              NaN                    NaN
# 3                      0.0  ...              NaN                    NaN
# 4                      0.0  ...              NaN                    NaN
# ...                    ...  ...              ...                    ...
# 44147                  NaN  ...              NaN                    NaN
# 44148                  NaN  ...              NaN                    NaN
# 44149                  NaN  ...              NaN                    NaN
# 44150                  NaN  ...              NaN                    NaN
# 44151                  NaN  ...              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                    11.62             NaN           NaN
# 1                    11.62             NaN           NaN
# 2                    11.62             NaN           NaN
# 3                    11.62             NaN           NaN
# 4                    11.62             NaN           NaN
# ...                    ...             ...           ...
# 44147                  NaN             NaN           NaN
# 44148                  NaN             NaN           NaN
# 44149                  NaN             NaN           NaN
# 44150                  NaN             NaN           NaN
# 44151                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                         NaN                         NaN            76.29
# 1                         NaN                         NaN            76.29
# 2                         NaN                         NaN            76.29
# 3                         NaN                         NaN            76.29
# 4                         NaN                         NaN            76.29
# ...                       ...                         ...              ...
# 44147                     NaN                         NaN              NaN
# 44148                     NaN                         NaN              NaN
# 44149                     NaN                         NaN              NaN
# 44150                     NaN                         NaN              NaN
# 44151                     NaN                         NaN              NaN
#
#        human_development_index  death_rate
# 0                          NaN         0.0
# 1                          NaN         NaN
# 2                          NaN         0.0
# 3                          NaN         NaN
# 4                          NaN         NaN
# ...                        ...         ...
# 44147                      NaN         0.0
# 44148                      NaN         0.0
# 44149                      NaN         0.0
# 44150                      NaN         0.0
# 44151                      NaN         0.0
#
# [44152 rows x 42 columns]

# %%
covid1.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'death_rate'],
#       dtype='object')

# %%
column_names = list(covid1)

# %%
death_data = ["new_deaths", "new_deaths_per_million", "total_deaths", "total_deaths_per_million", "death_rate"] # add death rate(and cadiovascular deaths?)
cases_data = ["new_cases", "new_cases_per_million", "total_cases", "new_cases_per_million"]
test_data = ["new_tests", "total_tests", "total_tests_per_thousand", "new_tests_per_thousand", "tests_per_case", "positive_rate"] # tests_units(?)
population_data = ["population", "population_density", "median_age", "aged_65_older", "aged_70_older", "gdp_per_capita", "extreme_poverty"]
misc_data = ["diabetes_prevelance", "female_smokers", "male_smokers", "handwashing_facilities", "hospital_beds_per_thousand", "life_expectancy", "human_development_index", "stringency_index"]

# %%
d1 = widgets.Dropdown(description = "Choose One", options = ['death', 'cases', 'test', "population", "misc", "correlations"])
def on_change(change):
    tempcovid = covid1.copy(deep = True)
    cols = list(tempcovid)
    if (change.new == 'death'):
        data1 = death_data
    if (change.new == 'cases'):
        data1 = cases_data
    if (change.new == 'test'):
        data1 = test_data
    if (change.new == 'population'):
        data1 = population_data
    if (change.new == 'misc'):
        data1 = misc_data
    print(data1)
    tempcovid = tempcovid[[data1]]
    display(tempcovid)
d1.observe(on_change, names = 'value')
display(d1)
# Out:
# Dropdown(description='Choose One', options=('death', 'cases', 'test', 'population', 'misc', 'correlations'), v…
# ['new_cases', 'new_cases_per_million', 'total_cases', 'new_cases_per_million']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# /opt/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget_selection.py in _propagate_index(self, change)
#     233             self.label = label
#     234         if self.value is not value:
# --> 235             self.value = value
#     236
#     237     @validate('value')
#
# /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1137             new=new_value,
#    1138             owner=self,
# -> 1139             type='change',
#    1140         ))
#    1141
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# <ipython-input-84-cbef9ca14728> in on_change(change)
#      14         data1 = misc_data
#      15     print(data1)
# ---> 16     tempcovid = tempcovid[[data1]]
#      17     display(tempcovid)
#      18 d1.observe(on_change, names = 'value')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index([('new_cases', 'new_cases_per_million', 'total_cases', 'new_cases_per_million')], dtype='object')] are in the [columns]"

# %%
d1 = widgets.Dropdown(description = "Choose One", options = ['death', 'cases', 'test', "population", "misc", "correlations"])

output_value = widgets.Output()

def on_change1(change):
    data1 = death_data
    output_value.clear_output()
    with output_value:
        if (change.new == 'death'):
            data1 = death_data
        if (change.new == 'cases'):
            data1 = cases_data
        if (change.new == 'test'):
            data1 = test_data
        if (change.new == 'population'):
            data1 = population_data
        if (change.new == 'misc'):
            data1 = misc_data
#     if (change.new == 'correlation'):
#         data1 = death_data
        d2 = widgets.Dropdown(description = change.new, options = data1)
        d2.observe(on_change1, names= 'value')
        display(d2)
d1.observe(on_change1, names = 'value')
display(d1)
# Out:
# Dropdown(description='Choose One', options=('death', 'cases', 'test', 'population', 'misc', 'correlations'), v…

# %%
display(output_value)
# Out:
# Output()

# %%
d1.value
# Out:
# 'misc'

# %%
ALL = 'ALL'
def unique_sorted_values_plus_ALL(array):
    unique = array.unique().tolist()
    unique.sort()
    unique.insert(0, ALL)
    return unique

Today = 'Today'
def unique_sorted_values_plus_today(array):
    unique = array.unique().tolist()
    unique.sort(reverse = True)
    unique.insert(0, Today)
    return unique

# %%
large_output = widgets.output()

def dropdown_creator(value):
    
dropdown_location = widgets.Dropdown(options = unique_sorted_values_plus_ALL(covid1.location))
dropdown_date1 = widgets.Dropdown(options = unique_sorted_values_plus_ALL(covid1.date))
dropdown_date2 = widgets.Dropdown(options = unique_sorted_values_plus_ALL(covid1.date))

def common_filtering(year, purpose):
    output.clear_output()
    
    if (year == ALL) & (purpose == ALL):
        common_filter = df_london
    elif (year == ALL):
        common_filter = df_london[df_london.purpose == purpose]
    elif (purpose == ALL):
        common_filter = df_london[df_london.year == year]
    else:
        common_filter = df_london[(df_london.year == year) & 
                                  (df_london.purpose == purpose)]
    
    with output:
        display(common_filter)

def dropdown_location_eventhandler(change):
    output_location.clear_output()
    with output_location:
        if (change.new == ALL):
            display(covid1)
        else:
            display((covid1[covid1.location == change.new]).head(10))
dropdown_location.observe(dropdown_location_eventhandler, names = 'value')
display(dropdown_location)
# Out:
# Dropdown(options=('ALL', 'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla', 'Antigua and Ba…

# %%
display(output_location)
# Out:
# Output()

# %%
print(datetime.today().strftime('%Y-%m-%d'))
# Out:
# 2020-09-25

# %%
now = pd.to_datetime('now')
last2 = now - pd.DateOffset(months=1)
covid1[covid1.date >= str(last2)]
print(now)
# Out:
# 2020-09-25 17:25:42.574696

# %%
unique_sorted_values_plus_today(covid1.date)
# Out:
# ['Today',
#  '2020-09-16',
#  '2020-09-15',
#  '2020-09-14',
#  '2020-09-13',
#  '2020-09-12',
#  '2020-09-11',
#  '2020-09-10',
#  '2020-09-09',
#  '2020-09-08',
#  '2020-09-07',
#  '2020-09-06',
#  '2020-09-05',
#  '2020-09-04',
#  '2020-09-03',
#  '2020-09-02',
#  '2020-09-01',
#  '2020-08-31',
#  '2020-08-30',
#  '2020-08-29',
#  '2020-08-28',
#  '2020-08-27',
#  '2020-08-26',
#  '2020-08-25',
#  '2020-08-24',
#  '2020-08-23',
#  '2020-08-22',
#  '2020-08-21',
#  '2020-08-20',
#  '2020-08-19',
#  '2020-08-18',
#  '2020-08-17',
#  '2020-08-16',
#  '2020-08-15',
#  '2020-08-14',
#  '2020-08-13',
#  '2020-08-12',
#  '2020-08-11',
#  '2020-08-10',
#  '2020-08-09',
#  '2020-08-08',
#  '2020-08-07',
#  '2020-08-06',
#  '2020-08-05',
#  '2020-08-04',
#  '2020-08-03',
#  '2020-08-02',
#  '2020-08-01',
#  '2020-07-31',
#  '2020-07-30',
#  '2020-07-29',
#  '2020-07-28',
#  '2020-07-27',
#  '2020-07-26',
#  '2020-07-25',
#  '2020-07-24',
#  '2020-07-23',
#  '2020-07-22',
#  '2020-07-21',
#  '2020-07-20',
#  '2020-07-19',
#  '2020-07-18',
#  '2020-07-17',
#  '2020-07-16',
#  '2020-07-15',
#  '2020-07-14',
#  '2020-07-13',
#  '2020-07-12',
#  '2020-07-11',
#  '2020-07-10',
#  '2020-07-09',
#  '2020-07-08',
#  '2020-07-07',
#  '2020-07-06',
#  '2020-07-05',
#  '2020-07-04',
#  '2020-07-03',
#  '2020-07-02',
#  '2020-07-01',
#  '2020-06-30',
#  '2020-06-29',
#  '2020-06-28',
#  '2020-06-27',
#  '2020-06-26',
#  '2020-06-25',
#  '2020-06-24',
#  '2020-06-23',
#  '2020-06-22',
#  '2020-06-21',
#  '2020-06-20',
#  '2020-06-19',
#  '2020-06-18',
#  '2020-06-17',
#  '2020-06-16',
#  '2020-06-15',
#  '2020-06-14',
#  '2020-06-13',
#  '2020-06-12',
#  '2020-06-11',
#  '2020-06-10',
#  '2020-06-09',
#  '2020-06-08',
#  '2020-06-07',
#  '2020-06-06',
#  '2020-06-05',
#  '2020-06-04',
#  '2020-06-03',
#  '2020-06-02',
#  '2020-06-01',
#  '2020-05-31',
#  '2020-05-30',
#  '2020-05-29',
#  '2020-05-28',
#  '2020-05-27',
#  '2020-05-26',
#  '2020-05-25',
#  '2020-05-24',
#  '2020-05-23',
#  '2020-05-22',
#  '2020-05-21',
#  '2020-05-20',
#  '2020-05-19',
#  '2020-05-18',
#  '2020-05-17',
#  '2020-05-16',
#  '2020-05-15',
#  '2020-05-14',
#  '2020-05-13',
#  '2020-05-12',
#  '2020-05-11',
#  '2020-05-10',
#  '2020-05-09',
#  '2020-05-08',
#  '2020-05-07',
#  '2020-05-06',
#  '2020-05-05',
#  '2020-05-04',
#  '2020-05-03',
#  '2020-05-02',
#  '2020-05-01',
#  '2020-04-30',
#  '2020-04-29',
#  '2020-04-28',
#  '2020-04-27',
#  '2020-04-26',
#  '2020-04-25',
#  '2020-04-24',
#  '2020-04-23',
#  '2020-04-22',
#  '2020-04-21',
#  '2020-04-20',
#  '2020-04-19',
#  '2020-04-18',
#  '2020-04-17',
#  '2020-04-16',
#  '2020-04-15',
#  '2020-04-14',
#  '2020-04-13',
#  '2020-04-12',
#  '2020-04-11',
#  '2020-04-10',
#  '2020-04-09',
#  '2020-04-08',
#  '2020-04-07',
#  '2020-04-06',
#  '2020-04-05',
#  '2020-04-04',
#  '2020-04-03',
#  '2020-04-02',
#  '2020-04-01',
#  '2020-03-31',
#  '2020-03-30',
#  '2020-03-29',
#  '2020-03-28',
#  '2020-03-27',
#  '2020-03-26',
#  '2020-03-25',
#  '2020-03-24',
#  '2020-03-23',
#  '2020-03-22',
#  '2020-03-21',
#  '2020-03-20',
#  '2020-03-19',
#  '2020-03-18',
#  '2020-03-17',
#  '2020-03-16',
#  '2020-03-15',
#  '2020-03-14',
#  '2020-03-13',
#  '2020-03-12',
#  '2020-03-11',
#  '2020-03-10',
#  '2020-03-09',
#  '2020-03-08',
#  '2020-03-07',
#  '2020-03-06',
#  '2020-03-05',
#  '2020-03-04',
#  '2020-03-03',
#  '2020-03-02',
#  '2020-03-01',
#  '2020-02-29',
#  '2020-02-28',
#  '2020-02-27',
#  '2020-02-26',
#  '2020-02-25',
#  '2020-02-24',
#  '2020-02-23',
#  '2020-02-22',
#  '2020-02-21',
#  '2020-02-20',
#  '2020-02-19',
#  '2020-02-18',
#  '2020-02-17',
#  '2020-02-16',
#  '2020-02-15',
#  '2020-02-14',
#  '2020-02-13',
#  '2020-02-12',
#  '2020-02-11',
#  '2020-02-10',
#  '2020-02-09',
#  '2020-02-08',
#  '2020-02-07',
#  '2020-02-06',
#  '2020-02-05',
#  '2020-02-04',
#  '2020-02-03',
#  '2020-02-02',
#  '2020-02-01',
#  '2020-01-31',
#  '2020-01-30',
#  '2020-01-29',
#  '2020-01-28',
#  '2020-01-27',
#  '2020-01-26',
#  '2020-01-25',
#  '2020-01-24',
#  '2020-01-23',
#  '2020-01-22',
#  '2020-01-21',
#  '2020-01-20',
#  '2020-01-19',
#  '2020-01-18',
#  '2020-01-17',
#  '2020-01-16',
#  '2020-01-15',
#  '2020-01-14',
#  '2020-01-13',
#  '2020-01-12',
#  '2020-01-11',
#  '2020-01-10',
#  '2020-01-09',
#  '2020-01-08',
#  '2020-01-07',
#  '2020-01-06',
#  '2020-01-05',
#  '2020-01-04',
#  '2020-01-03',
#  '2020-01-02',
#  '2020-01-01',
#  '2019-12-31']
